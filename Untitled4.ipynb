# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !pip install -q pyspark

# %%
import pyspark, os
import math
from math import sqrt
from math import log
from random import seed
from random import randint
from pyspark import SparkConf, SparkContext
os.environ["PYSPARK_PYTHON"]="python3"
os.environ["JAVA_HOME"]="/usr/lib/jvm/java-8-openjdk-amd64/"

#connects our python driver to a local Spark JVM running on the Google Colab server virtual machine
try:
  conf = SparkConf().setMaster("local[*]").set("spark.executor.memory", "1g")
  sc = SparkContext(conf = conf)
except ValueError:
  #it's ok if the server is already started
  pass


#also include this short helper function for use later in this lab
def dbg(x):
  """ A helper function to print debugging information on RDDs """
  if isinstance(x, pyspark.RDD):
    print([(t[0], list(t[1]) if 
            isinstance(t[1], pyspark.resultiterable.ResultIterable) else t[1])
           if isinstance(t, tuple) else t
           for t in x.take(100)])
  else:
    print(x)

# %% [markdown]
# Create a python Spark program that does the following:
#
# 1. Loads each line of the text file pg16328.txt as an entry in an RDD:  https://www.gutenberg.org/cache/epub/16328/pg16328.txt
# hint: you can use this in your colab notebook to download the file automatically:
# !wget "https://www.gutenberg.org/cache/epub/16328/pg16328.txt"
#
# 2. Maps each RDD entry so that each entry contains a tuple of (lowercase set of letters, the original line) (hint: use python's set(), lower(), and isalpha() method on strings). For example the following line:
#
# "{The famous race of Spear-Danes.}"
#
# would be represented as the tuple
#
# ({'a', 'c', 'd', 'e', 'f', 'h', 'm', 'n', 'o', 'p', 'r', 's', 't', 'u'}, "{The famous race of Spear-Danes.}")
#
# 3. Finds and prints the 5 lines in the file with the highest Jaccard Similarity to your full name. Recall that Jaccard Similarity is the size of the intersection / size of the union of two sets. For example using my name "James Atlas" the output should be:
#
# ['States.', '1859. Alliterative measures.', 'BATTLE-SARK.--Armor.', '{The gleeman sings}', '          Than the head and the handle handsome with jewels;']
#
#
# Full credit for efficient solutions that use Spark functions
#
# Here is an example colab starter for Spark:
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !pip install -q pyspark
# import os
# os.environ["PYSPARK_PYTHON"]="python3"
# os.environ["JAVA_HOME"]="/usr/lib/jvm/java-8-openjdk-amd64/"
#
# import pyspark
# from pyspark import SparkConf, SparkContext
#
# conf = SparkConf().setMaster("local[*]").set("spark.executor.memory", "1g")
# sc = SparkContext(conf = conf)

# %%
# !wget "https://www.gutenberg.org/cache/epub/16328/pg16328.txt"
df = sc.textFile("pg16328.txt")

# Print the rdd of lines for marker
dbg(file)
# Out:
# --2020-06-16 04:24:24--  https://www.gutenberg.org/cache/epub/16328/pg16328.txt
# Resolving www.gutenberg.org (www.gutenberg.org)... 152.19.134.47, 2610:28:3090:3000:0:bad:cafe:47
# Connecting to www.gutenberg.org (www.gutenberg.org)|152.19.134.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 301063 (294K) [text/plain]
# Saving to: ‘pg16328.txt.6’
#
# pg16328.txt.6       100%[===================>] 294.01K  1.08MB/s    in 0.3s
#
# 2020-06-16 04:24:24 (1.08 MB/s) - ‘pg16328.txt.6’ saved [301063/301063]
#
# ['The Project Gutenberg EBook of Beowulf ', '', 'This eBook is for the use of anyone anywhere at no cost and with', 'almost no restrictions whatsoever.  You may copy it, give it away or', 're-use it under the terms of the Project Gutenberg License included', 'with this eBook or online at www.gutenberg.net', '', '', 'Title: Beowulf', '       An Anglo-Saxon Epic Poem, Translated From The Heyne-Socin', '       Text by Lesslie Hall', '', 'Author:  ', '', 'Release Date: July 19, 2005 [EBook #16328]', '', 'Language: English', '', '', '*** START OF THIS PROJECT GUTENBERG EBOOK BEOWULF ***', '', '', '', '', 'Produced by David Starner, Dainis Millers and the Online', 'Distributed Proofreading Team at http://www.pgdp.net', '', '', '', '', '', '', '', 'BEOWULF', 'AN ANGLO-SAXON EPIC POEM', '', '_TRANSLATED FROM THE HEYNE-SOCIN TEXT_', '', 'BY', '', 'JNO: LESSLIE HALL, Ph. D. (J.H.U.)', '', 'Professor of English and History in The College of William and Mary', '', '', 'D.C. HEATH & CO., PUBLISHERS', 'BOSTON NEW YORK CHICAGO', '', '', 'Entered according to Act of Congress, in the year 1892, by', '', 'JNO: LESSLIE HALL,', '', 'in the Office of the Librarian of Congress, at Washington.', '', '', 'TO', '', 'My Wife', '', '[v]', '', '', '', '', 'CONTENTS.', '', '', '                                                               PAGE', '', '      Preface                                                   vii', '', '      Bibliography of Translations                               xi', '', '      Glossary of Proper Names                                 xiii', '', '      List of Words and Phrases not in General Use            xviii', '', '      The Life and Death of Scyld (I.)                            1', '', "      Scyld's Successors", '                                 } (II.)                          3', "      Hrothgar's Great Mead-Hall", '', '      Grendel, the Murderer (III.)                                5', '', "      Beowulf Goes to Hrothgar's Assistance (IV.)                 8", '', '      The Geats Reach Heorot (V.)                                10', '', '      Beowulf Introduces Himself at the Palace (VI.)             12', '', '      Hrothgar and Beowulf (VII.)                                14', '', '      Hrothgar and Beowulf (continued) (VIII.)                   17', '', '      Unferth Taunts Beowulf (IX.)                               19', '', '      Beowulf Silences Unferth', '                               } (X.)                            21']

# %%
def strip_words(file):
  """for char in lines set them to lower and get rid of non letters, returns set of them as lower case"""
  letter_list = []
  for letter in file:
    if letter.isalpha():
      letter_list.append(letter.lower())
  return set(letter_list)

# %%
values = df.map(lambda x: (strip_words(x), x))
# Print for marker
dbg(values)
# Out:
# [({'b', 'j', 'o', 't', 'w', 'g', 'p', 'f', 'u', 'e', 'n', 'k', 'r', 'c', 'l', 'h'}, 'The Project Gutenberg EBook of Beowulf '), (set(), ''), ({'s', 'b', 'a', 'o', 't', 'w', 'f', 'e', 'u', 'n', 'k', 'r', 'c', 'd', 'i', 'h', 'y'}, 'This eBook is for the use of anyone anywhere at no cost and with'), ({'s', 'm', 'a', 'o', 't', 'w', 'g', 'p', 'v', 'e', 'u', 'n', 'r', 'c', 'l', 'i', 'h', 'y'}, 'almost no restrictions whatsoever.  You may copy it, give it away or'), ({'s', 'b', 'm', 'j', 'o', 't', 'g', 'p', 'f', 'u', 'e', 'n', 'r', 'c', 'l', 'd', 'i', 'h'}, 're-use it under the terms of the Project Gutenberg License included'), ({'s', 'b', 'a', 'o', 't', 'w', 'g', 'u', 'e', 'n', 'k', 'r', 'l', 'i', 'h'}, 'with this eBook or online at www.gutenberg.net'), (set(), ''), (set(), ''), ({'b', 'o', 't', 'w', 'f', 'u', 'e', 'l', 'i'}, 'Title: Beowulf'), ({'s', 'm', 'a', 'o', 't', 'g', 'p', 'x', 'f', 'e', 'n', 'r', 'c', 'l', 'd', 'i', 'h', 'y'}, '       An Anglo-Saxon Epic Poem, Translated From The Heyne-Socin'), ({'s', 'b', 'a', 't', 'x', 'e', 'l', 'i', 'h', 'y'}, '       Text by Lesslie Hall'), (set(), ''), ({'a', 't', 'o', 'u', 'r', 'h'}, 'Author:  '), (set(), ''), ({'s', 'b', 'a', 'j', 'o', 't', 'u', 'e', 'k', 'r', 'l', 'd', 'y'}, 'Release Date: July 19, 2005 [EBook #16328]'), (set(), ''), ({'s', 'a', 'g', 'u', 'e', 'n', 'l', 'i', 'h'}, 'Language: English'), (set(), ''), (set(), ''), ({'s', 'b', 'a', 'j', 'o', 't', 'w', 'g', 'p', 'f', 'e', 'u', 'n', 'k', 'r', 'c', 'l', 'i', 'h'}, '*** START OF THIS PROJECT GUTENBERG EBOOK BEOWULF ***'), (set(), ''), (set(), ''), (set(), ''), (set(), ''), ({'s', 'b', 'a', 'm', 'o', 't', 'h', 'p', 'v', 'u', 'e', 'n', 'r', 'c', 'l', 'i', 'd', 'y'}, 'Produced by David Starner, Dainis Millers and the Online'), ({'s', 'b', 'a', 'm', 'o', 't', 'w', 'g', 'p', 'f', 'u', 'e', 'n', 'r', 'd', 'i', 'h'}, 'Distributed Proofreading Team at http://www.pgdp.net'), (set(), ''), (set(), ''), (set(), ''), (set(), ''), (set(), ''), (set(), ''), (set(), ''), ({'b', 'o', 'w', 'f', 'u', 'e', 'l'}, 'BEOWULF'), ({'s', 'm', 'a', 'o', 'g', 'p', 'x', 'e', 'n', 'c', 'l', 'i'}, 'AN ANGLO-SAXON EPIC POEM'), (set(), ''), ({'s', 'm', 'a', 'o', 't', 'x', 'f', 'e', 'n', 'r', 'c', 'l', 'd', 'i', 'h', 'y'}, '_TRANSLATED FROM THE HEYNE-SOCIN TEXT_'), (set(), ''), ({'b', 'y'}, 'BY'), (set(), ''), ({'s', 'a', 'j', 'o', 'p', 'u', 'e', 'n', 'l', 'd', 'i', 'h'}, 'JNO: LESSLIE HALL, Ph. D. (J.H.U.)'), (set(), ''), ({'s', 'm', 'a', 'o', 't', 'w', 'g', 'p', 'f', 'e', 'n', 'r', 'c', 'l', 'd', 'i', 'h', 'y'}, 'Professor of English and History in The College of William and Mary'), (set(), ''), (set(), ''), ({'s', 'b', 'a', 'o', 't', 'p', 'u', 'e', 'r', 'c', 'l', 'd', 'i', 'h'}, 'D.C. HEATH & CO., PUBLISHERS'), ({'s', 'b', 'a', 'o', 't', 'w', 'g', 'e', 'n', 'k', 'r', 'c', 'i', 'h', 'y'}, 'BOSTON NEW YORK CHICAGO'), (set(), ''), (set(), ''), ({'s', 'b', 'a', 'o', 't', 'g', 'f', 'e', 'n', 'r', 'c', 'd', 'i', 'h', 'y'}, 'Entered according to Act of Congress, in the year 1892, by'), (set(), ''), ({'s', 'a', 'j', 'o', 'e', 'n', 'l', 'i', 'h'}, 'JNO: LESSLIE HALL,'), (set(), ''), ({'s', 'b', 'a', 'o', 't', 'w', 'g', 'f', 'e', 'n', 'r', 'c', 'l', 'i', 'h'}, 'in the Office of the Librarian of Congress, at Washington.'), (set(), ''), (set(), ''), ({'o', 't'}, 'TO'), (set(), ''), ({'m', 'w', 'f', 'e', 'i', 'y'}, 'My Wife'), (set(), ''), ({'v'}, '[v]'), (set(), ''), (set(), ''), (set(), ''), (set(), ''), ({'s', 'o', 't', 'e', 'n', 'c'}, 'CONTENTS.'), (set(), ''), (set(), ''), ({'e', 'g', 'a', 'p'}, '                                                               PAGE'), (set(), ''), ({'a', 'p', 'v', 'f', 'e', 'r', 'c', 'i'}, '      Preface                                                   vii'), (set(), ''), ({'s', 'b', 'a', 'o', 't', 'g', 'p', 'x', 'f', 'n', 'r', 'l', 'i', 'h', 'y'}, '      Bibliography of Translations                               xi'), (set(), ''), ({'s', 'm', 'a', 'o', 'g', 'p', 'x', 'f', 'e', 'n', 'r', 'l', 'i', 'y'}, '      Glossary of Proper N ...

# %%
name = ['j', 'a', 'm', 'e', 's', 'a', 't', 'l', 'a', 's']
my_name = ['g', 'r', 'e', 'y', 'h', 'a', 'r', 'r', 'i', 's']

# %%
def jaccard_similarity(list1, list2):
	"""calculates the jaccard similarity"""
	set_one = set(list1)
	set_two = set(list2)
	return len(set_one.intersection(set_two)) / len(set_one.union(set_two))

results = values.map(lambda x: (jaccard_similarity(x[0], my_name), x[1]))
results_sorted = results.sortByKey(ascending=False)
dbg(results_sorted)
# Out:
# [(0.7, 'BIGHT.--Bay, sea.'), (0.7, '{Hrothgar retires.}'), (0.7, '    he arose again_.'), (0.6666666666666666, '{He rules the Geats fifty years.}'), (0.6666666666666666, '        5 Then the trusty retainer treasure-gems many'), (0.6363636363636364, 'TARGE, TARGET.--Shield.'), (0.6363636363636364, "       45 High on his horse then Hrothgar's retainer"), (0.6363636363636364, '{The waters are gory.}'), (0.6153846153846154, '      Wiglaf the Trusty'), (0.6153846153846154, 'his goodness of heart, and his generosity._'), (0.6, 'see the strangers.}'), (0.5833333333333334, "      Hrothgar's Gratitude"), (0.5833333333333334, '       35 That greater strength in the waters I had then,'), (0.5833333333333334, "HROTHGAR'S GRATITUDE."), (0.5833333333333334, '    _Seized by the hair_.'), (0.5833333333333334, '          To the royal ring-hall, Hrothgar to greet there:'), (0.5833333333333334, '{All my gifts I lay at thy feet.}'), (0.5833333333333334, "{Higelac's death recalled.}"), (0.5833333333333334, '       55 A song of sorrow, when his son is hanging'), (0.5833333333333334, '{The dragon is not there.}'), (0.5833333333333334, "{The hero's last gift}"), (0.5833333333333334, "{Higelac's death recalled.}"), (0.5833333333333334, "'eal' he says _nom. sing._"), (0.5714285714285714, 'short lines, generally containing two stresses.'), (0.5714285714285714, '          A son and heir, young in his dwelling,'), (0.5714285714285714, '          "\'Tis time I were faring; Father Almighty'), (0.5714285714285714, '          [2]Old and hoary, his earlmen attending him;'), (0.5714285714285714, '          The mighty one rose then, with many a liegeman,'), (0.5714285714285714, '[16]      The giant-race wasted, in the waters destroying'), (0.5714285714285714, '          That _I_ may unaided, my earlmen assisting me,'), (0.5714285714285714, '          God can easily hinder the scather'), (0.5714285714285714, "          Hearty in Heorot; there was heroes' rejoicing,"), (0.5714285714285714, '          To shatter my shield, though sure he is mighty'), (0.5714285714285714, "{Grendel's cries terrify the Danes.}"), (0.5714285714285714, '          In the mist of the morning many a warrior'), (0.5714285714285714, '          Measured the mead-ways, with maidens attending.'), (0.5714285714285714, '          Its hinges torn off: only the roof was'), (0.5714285714285714, '          The war-youth together; there the good one was sitting'), (0.5714285714285714, '{May gifts never fail thee.}'), (0.5714285714285714, '          Bright-shining targets, up by their heads then;'), (0.5714285714285714, "       25 The son of the athelings then went o'er the stony,"), (0.5714285714285714, '          Trying the waters, nickers a-lying'), (0.5714285714285714, "          Grisly and greedy, that the grim one's dominion"), (0.5714285714285714, '       45 The mighty mere-woman; he made a great onset'), (0.5714285714285714, '          The hoary of head, that they hoped not to see again'), (0.5714285714285714, '          Nor sickness nor age, no treachery-sorrow'), (0.5714285714285714, '          Wielder of Glory. His end-day anear,'), (0.5714285714285714, '          When the warriors were ready, arrayed in their trappings,'), (0.5714285714285714, '          Had in lordly language saluted the dear one,'), (0.5714285714285714, '          From many of men, the meeting so famous,'), (0.5714285714285714, '          He bare on his arm, lone-going, thirty'), (0.5714285714285714, "          Becoming an enemy. Ohthere's son then"), (0.5714285714285714, "          To behold the hoard 'neath the hoar-grayish stone,"), (0.5714285714285714, '          The ornament-armor wherein ye are standing,'), (0.5714285714285714, '          By the deeds of the dragon in death-bed abideth;'), (0.5714285714285714, "       35 Early did Ohthere's age-laden father,"), (0.5714285714285714, '          Fain over fey ones freely shall gabble,'), (0.5714285714285714, '          Ghostly and grisly guest in his terrors,'), (0.55 ...

# %%
results_sorted.map(lambda x: x[1]).take(5)
# Out:
# ['BIGHT.--Bay, sea.',
#  '{Hrothgar retires.}',
#  '    he arose again_.',
#  '{He rules the Geats fifty years.}',
#  '        5 Then the trusty retainer treasure-gems many']
